# %%
import os
import yfinance as yf
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, LSTM
import joblib

def download_and_clean_stock_data():
    """
    Download stock data for the Magnificent Seven, clean it, and save as CSV files.
    """
    stocks = ["AAPL", "MSFT", "GOOGL", "AMZN", "META", "NVDA", "TSLA"]
    output_dir = "raw_stock_data"
    os.makedirs(output_dir, exist_ok=True)

    def save_cleaned_data(data, stock, output_path):
        # Reset index to turn the Date index into a column
        data.reset_index(inplace=True)
        # Retain only the desired columns
        data = data[["Date", "Open", "High", "Low", "Close", "Volume"]]
        # Add a Ticker column
        data["Ticker"] = stock
        # Save the data to CSV
        data.to_csv(output_path, index=False)
        # Reload and remove the first row (if needed)
        data = pd.read_csv(output_path)
        data = data.iloc[1:]
        data.to_csv(output_path, index=False)

    for stock in stocks:
        data = yf.download(stock, start="2015-01-01", end="2025-01-01")
        output_path = os.path.join(output_dir, f"{stock}.csv")
        save_cleaned_data(data, stock, output_path)
        # print(f"Saved cleaned data for {stock} at {output_path}")

def preprocess_data():
    """
    Preprocess each stock's data by converting dates, sorting, and adding new features.
    The processed CSV files are saved into a separate folder.
    """
    data_dir = "raw_stock_data"
    output_dir = "processed_stock_data"
    os.makedirs(output_dir, exist_ok=True)

    def preprocess_stock_data(file_path):
        data = pd.read_csv(file_path)
        # Convert Date to datetime and sort
        data["Date"] = pd.to_datetime(data["Date"])
        data.sort_values(by="Date", inplace=True)
        # Calculate additional features
        data["Daily Return"] = data["Close"].pct_change()
        data["5-Day Moving Avg"] = data["Close"].rolling(window=5).mean()
        data["10-Day Volatility"] = data["Close"].rolling(window=10).std()
        # Remove rows with NaN values from rolling calculations
        data.dropna(inplace=True)
        return data

    for file_name in os.listdir(data_dir):
        if file_name.endswith(".csv"):
            stock_file_path = os.path.join(data_dir, file_name)
            stock_name = os.path.splitext(file_name)[0]
            # print(f"Processing data for {stock_name}...")
            processed_data = preprocess_stock_data(stock_file_path)
            output_path = os.path.join(output_dir, f"{stock_name}_processed.csv")
            processed_data.to_csv(output_path, index=False)
            # print(f"Saved processed data for {stock_name} to {output_path}")
    # print("Data preprocessing complete!")

def load_stock_data(file_path):
    """
    Load processed data from a CSV file and prepare features and target.
    The target is the next day's closing price.
    """
    data = pd.read_csv(file_path)
    features = data[["Open", "High", "Low", "Close", "Volume", "5-Day Moving Avg", "10-Day Volatility"]]
    target = data["Close"].shift(-1)
    # Drop the last row (where target is NaN)
    features = features[:-1]
    target = target[:-1]
    return features, target

def train_model():
    """
    Load the AAPL processed data, split into training and testing sets,
    build and train a neural network with LSTM layers, and save the model.
    """
    processed_data_dir = "processed_stock_data"
    stock_file_path = os.path.join(processed_data_dir, "AAPL_processed.csv")
    features, target = load_stock_data(stock_file_path)

    # Split the data into training and testing sets
    X_train, X_test, y_train, y_test = train_test_split(
        features.values, target.values, test_size=0.2, random_state=42
    )

    # Reshape data for LSTM: (samples, timesteps, features)
    X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
    X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

    # Build the LSTM model
    model = Sequential()
    model.add(LSTM(50, return_sequences=True, input_shape=(X_train.shape[1], 1)))
    model.add(LSTM(50))
    model.add(Dense(1))
    model.compile(optimizer="adam", loss="mean_squared_error")

    # print("Training the model...")
    model.fit(X_train, y_train, epochs=1000, batch_size=32, verbose=1)

    # print("Evaluating the model on the test set...")
    loss = model.evaluate(X_test, y_test)
    # print(f"Test Loss: {loss}")

    # Save the trained model
    joblib.dump(model,"models/AAPL_model.joblib")
    # model.save("models/AAPL_model.h5")
    # print("Model saved as 'models/AAPL_model.h5'")

def evaluate_model():
    """
    Evaluate the saved model on a portion of AAPL's data and # print error metrics.
    Also, predict the next few days' closing prices and save these predictions to CSV.
    """
    processed_data_dir = "processed_stock_data"
    model_path = "stock_price_predictor.h5"
    model = load_model(model_path)

    def load_evaluation_data(file_path):
        data = pd.read_csv(file_path)
        features = data[["Open", "High", "Low", "Close", "Volume", "5-Day Moving Avg", "10-Day Volatility"]]
        target = data["Close"].shift(-1)
        features = features[:-1]
        target = target[:-1]
        # Use the last 10 rows for evaluation (e.g., next days' predictions)
        evaluation_features = features[-10:]
        evaluation_target = target[-10:]
        # Remove the evaluation portion from the main dataset
        features = features[:-10]
        target = target[:-10]
        return features, target, evaluation_features, evaluation_target

    stock_file_path = os.path.join(processed_data_dir, "AAPL_processed.csv")
    features, target, eval_features, eval_target = load_evaluation_data(stock_file_path)

    # Reshape data for LSTM input
    X_train = np.reshape(features.values, (features.shape[0], features.shape[1], 1))
    X_eval = np.reshape(eval_features.values, (eval_features.shape[0], eval_features.shape[1], 1))

    # Evaluate on the training portion (without the last few evaluation rows)
    predicted_train = model.predict(X_train)
    mse = mean_squared_error(target, predicted_train)
    mae = mean_absolute_error(target, predicted_train)
    r2 = r2_score(target, predicted_train)
    
    # print("### Model Evaluation on Training Data ###")
    # print(f"Mean Squared Error (MSE): {mse:.4f}")
    # print(f"Mean Absolute Error (MAE): {mae:.4f}")
    # print(f"R-squared (R2): {r2:.4f}")

    # Predict the next days' prices using the evaluation features
    predicted_eval = model.predict(X_eval)
    results = pd.DataFrame({
        "Index": eval_features.index,
        "Actual Price": eval_target.values,
        "Predicted Price": predicted_eval.flatten()
    })

    # print("### Next Days' Predictions ###")
    # print(results)

    # Save predictions to a CSV file
    # results.to_csv("next_month_predictions.csv", index=False)
    # print("Predictions saved as 'next_month_predictions.csv'")

def main():
    # print("Starting the stock data pipeline...")
    download_and_clean_stock_data()
    preprocess_data()
    train_model()
    # evaluate_model()
    # print("Pipeline complete!")

if __name__ == '__main__':
    main()
# Out:
# [*********************100%***********************]  1 of 1 completed
# /var/folders/s_/kpvlk3bs5v7_vx6qt436qn400000gn/T/ipykernel_20558/1836356462.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Ticker"] = stock
# [*********************100%***********************]  1 of 1 completed
# /var/folders/s_/kpvlk3bs5v7_vx6qt436qn400000gn/T/ipykernel_20558/1836356462.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Ticker"] = stock
# [*********************100%***********************]  1 of 1 completed
# /var/folders/s_/kpvlk3bs5v7_vx6qt436qn400000gn/T/ipykernel_20558/1836356462.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Ticker"] = stock
# [*********************100%***********************]  1 of 1 completed
# /var/folders/s_/kpvlk3bs5v7_vx6qt436qn400000gn/T/ipykernel_20558/1836356462.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Ticker"] = stock
# [*********************100%***********************]  1 of 1 completed
# /var/folders/s_/kpvlk3bs5v7_vx6qt436qn400000gn/T/ipykernel_20558/1836356462.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Ticker"] = stock
# [*********************100%***********************]  1 of 1 completed
# /var/folders/s_/kpvlk3bs5v7_vx6qt436qn400000gn/T/ipykernel_20558/1836356462.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Ticker"] = stock
# [*********************100%***********************]  1 of 1 completed
# /var/folders/s_/kpvlk3bs5v7_vx6qt436qn400000gn/T/ipykernel_20558/1836356462.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Ticker"] = stock
# Epoch 1/1000
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 12958.8643
# Epoch 2/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 11199.3066
# Epoch 3/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 10709.7490
# Epoch 4/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9489.1719
# Epoch 5/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9153.8877
# Epoch 6/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8874.6641
# Epoch 7/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9042.5273
# Epoch 8/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8450.6035
# Epoch 9/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7867.6279
# Epoch 10/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7973.3369
# Epoch 11/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7503.0869
# Epoch 12/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6973.2861
# Epoch 13/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6409.8398
# Epoch 14/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6722.3130
# Epoch 15/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6347.7402
# Epoch 16/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5959.0522
# Epoch 17/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5931.7710
# Epoch 18/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6054.7754
# Epoch 19/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5690.6748
# Epoch 20/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5330.2236
# Epoch 21/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5304.1982
# Epoch 22/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5320.4238
# Epoch 23/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5306.1719
# Epoch 24/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5023.0693
# Epoch 25/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4986.7710
# Epoch 26/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5008.4531
# Epoch 27/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4645.7583
# Epoch 28/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4806.9473
# Epoch 29/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4645.5181
# Epoch 30/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4839.3594
# Epoch 31/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4536.8945
# Epoch 32/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4412.4204
# Epoch 33/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4527.7388
# Epoch 34/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4724.3936
# Epoch 35/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4385.5854
# Epoch 36/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3411.5803
# Epoch 37/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3018.8594
# Epoch 38/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2769.3140
# Epoch 39/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2597.8918
# Epoch 40/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2404.1721
# Epoch 41/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2199.1826
# Epoch 42/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2185.3760
# Epoch 43/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2009.9786
# Epoch 44/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1944.8649
# Epoch 45/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1738.5275
# Epoch 46/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1529.3539
# Epoch 47/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1641.1267
# Epoch 48/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1532.0984
# Epoch 49/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1253.3781
# Epoch 50/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1241.0709
# Epoch 51/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1176.4462
# Epoch 52/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1117.3375
# Epoch 53/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1109.0317
# Epoch 54/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1021.7059
# Epoch 55/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1001.0967
# Epoch 56/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 843.0353
# Epoch 57/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 868.8029
# Epoch 58/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 864.0018
# Epoch 59/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 742.3706
# Epoch 60/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 726.3868
# Epoch 61/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 702.1686
# Epoch 62/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 602.6260
# Epoch 63/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 605.5817
# Epoch 64/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 662.0948
# Epoch 65/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 571.6622
# Epoch 66/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 477.0782
# Epoch 67/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 454.7530
# Epoch 68/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 492.7221
# Epoch 69/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 444.8221
# Epoch 70/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 400.1764
# Epoch 71/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 408.7702
# Epoch 72/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 351.6333
# Epoch 73/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 336.3059
# Epoch 74/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 381.4764
# Epoch 75/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 349.5330
# Epoch 76/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 302.9329
# Epoch 77/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 300.9299
# Epoch 78/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 260.3262
# Epoch 79/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 249.5088
# Epoch 80/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 233.2408
# Epoch 81/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 277.1053
# Epoch 82/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 240.9462
# Epoch 83/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 268.2285
# Epoch 84/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 191.5654
# Epoch 85/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 195.0648
# Epoch 86/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 189.4107
# Epoch 87/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 186.9683
# Epoch 88/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 183.3346
# Epoch 89/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 193.8816
# Epoch 90/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 192.1457
# Epoch 91/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 143.7038
# Epoch 92/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 145.9069
# Epoch 93/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 177.2252
# Epoch 94/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 152.6246
# Epoch 95/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 145.5800
# Epoch 96/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 131.4755
# Epoch 97/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 111.7194
# Epoch 98/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 104.2375
# Epoch 99/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 88.7496
# Epoch 100/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 85.1009
# Epoch 101/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 99.2646
# Epoch 102/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 108.3329
# Epoch 103/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 96.3619
# Epoch 104/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 83.0067
# Epoch 105/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 75.3713
# Epoch 106/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 68.3412
# Epoch 107/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 89.1351
# Epoch 108/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 74.6705
# Epoch 109/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 64.2311
# Epoch 110/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 73.3837
# Epoch 111/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 87.7433
# Epoch 112/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 61.0134
# Epoch 113/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 61.2621
# Epoch 114/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 62.6337
# Epoch 115/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 51.7218
# Epoch 116/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 44.0546
# Epoch 117/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 41.3844
# Epoch 118/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 40.9584
# Epoch 119/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 41.5178
# Epoch 120/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 41.1250
# Epoch 121/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 45.3386
# Epoch 122/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 42.9251
# Epoch 123/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 34.2834
# Epoch 124/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 34.0716
# Epoch 125/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 35.5584
# Epoch 126/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 27.9788
# Epoch 127/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 23.7215
# Epoch 128/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 26.6856
# Epoch 129/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 27.8420
# Epoch 130/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 24.6268
# Epoch 131/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 23.8724
# Epoch 132/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 24.6397
# Epoch 133/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 21.0298
# Epoch 134/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 21.7881
# Epoch 135/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 19.9731
# Epoch 136/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 19.5110
# Epoch 137/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 18.3141
# Epoch 138/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 22.7037
# Epoch 139/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 13.4610
# Epoch 140/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 18.0484
# Epoch 141/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 14.4494
# Epoch 142/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 14.2383
# Epoch 143/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 12.3025
# Epoch 144/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 13.8944
# Epoch 145/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 15.8570
# Epoch 146/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 11.7204
# Epoch 147/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 12.8625
# Epoch 148/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 12.0307
# Epoch 149/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 11.4056
# Epoch 150/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 10.4064
# Epoch 151/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 10.4659
# Epoch 152/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 11.2955
# Epoch 153/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 11.3407
# Epoch 154/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 12.4481
# Epoch 155/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 10.1191
# Epoch 156/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.8243
# Epoch 157/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.8941
# Epoch 158/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.8818
# Epoch 159/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.6210
# Epoch 160/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.4408
# Epoch 161/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.2446
# Epoch 162/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 11.6303
# Epoch 163/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 11.1053
# Epoch 164/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.8223
# Epoch 165/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.9733
# Epoch 166/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.8037
# Epoch 167/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.2864
# Epoch 168/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.6927
# Epoch 169/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.1234
# Epoch 170/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.7272
# Epoch 171/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.9478
# Epoch 172/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.4678
# Epoch 173/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.7266
# Epoch 174/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.3257
# Epoch 175/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.5586
# Epoch 176/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.4658
# Epoch 177/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.3201
# Epoch 178/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.6392
# Epoch 179/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.7493
# Epoch 180/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.2363
# Epoch 181/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.0201
# Epoch 182/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.1481
# Epoch 183/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.9540
# Epoch 184/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.4575
# Epoch 185/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.8253
# Epoch 186/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.6700
# Epoch 187/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.2383
# Epoch 188/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.6260
# Epoch 189/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.7094
# Epoch 190/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.0115
# Epoch 191/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.0558
# Epoch 192/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.4696
# Epoch 193/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.1208
# Epoch 194/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.4194
# Epoch 195/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.8448
# Epoch 196/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.0108
# Epoch 197/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.6831
# Epoch 198/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.8651
# Epoch 199/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.4121
# Epoch 200/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.3138
# Epoch 201/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.7273
# Epoch 202/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.8227
# Epoch 203/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 10.2026
# Epoch 204/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.1541
# Epoch 205/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.1788
# Epoch 206/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.7494
# Epoch 207/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.4834
# Epoch 208/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.4157
# Epoch 209/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.5581
# Epoch 210/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.4280
# Epoch 211/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.2573
# Epoch 212/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.3049
# Epoch 213/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.2591
# Epoch 214/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.8861
# Epoch 215/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.4476
# Epoch 216/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.8634
# Epoch 217/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.7271
# Epoch 218/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.8761
# Epoch 219/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.4722
# Epoch 220/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.8130
# Epoch 221/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.4296
# Epoch 222/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.7472
# Epoch 223/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.6670
# Epoch 224/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.8158
# Epoch 225/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.7552
# Epoch 226/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.2231
# Epoch 227/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.8335
# Epoch 228/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.2436
# Epoch 229/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.1070
# Epoch 230/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.3352
# Epoch 231/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.6383
# Epoch 232/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.6950
# Epoch 233/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.5836
# Epoch 234/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0392
# Epoch 235/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.4401
# Epoch 236/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.3268
# Epoch 237/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.5946
# Epoch 238/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.4017
# Epoch 239/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.6895
# Epoch 240/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.4215
# Epoch 241/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.5555
# Epoch 242/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.2215
# Epoch 243/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.9217
# Epoch 244/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.1985
# Epoch 245/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.9747
# Epoch 246/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.1288
# Epoch 247/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.5961
# Epoch 248/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.3721
# Epoch 249/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.7596
# Epoch 250/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.4391
# Epoch 251/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.5776
# Epoch 252/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.1581
# Epoch 253/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.6188
# Epoch 254/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.2776
# Epoch 255/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.1750
# Epoch 256/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.2671
# Epoch 257/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.3717
# Epoch 258/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.8978
# Epoch 259/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5150
# Epoch 260/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7388
# Epoch 261/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.0900
# Epoch 262/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7912
# Epoch 263/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7540
# Epoch 264/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.0192
# Epoch 265/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.4738
# Epoch 266/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.7406
# Epoch 267/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6776
# Epoch 268/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6539
# Epoch 269/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.2987
# Epoch 270/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.5412
# Epoch 271/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.5936
# Epoch 272/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5638
# Epoch 273/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.9251
# Epoch 274/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.5747
# Epoch 275/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.9321
# Epoch 276/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.5797
# Epoch 277/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6960
# Epoch 278/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.3542
# Epoch 279/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.6874
# Epoch 280/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7002
# Epoch 281/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.0853
# Epoch 282/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8852
# Epoch 283/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8906
# Epoch 284/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8673
# Epoch 285/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0723
# Epoch 286/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.7425
# Epoch 287/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0983
# Epoch 288/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.9432
# Epoch 289/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5293
# Epoch 290/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0843
# Epoch 291/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.9739
# Epoch 292/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.4640
# Epoch 293/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6938
# Epoch 294/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.2418
# Epoch 295/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.9209
# Epoch 296/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4590
# Epoch 297/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7816
# Epoch 298/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.8120
# Epoch 299/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.4401
# Epoch 300/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0399
# Epoch 301/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0798
# Epoch 302/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.3279
# Epoch 303/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.7875
# Epoch 304/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.7866
# Epoch 305/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.5279
# Epoch 306/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.9372
# Epoch 307/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.4571
# Epoch 308/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.4343
# Epoch 309/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.9774
# Epoch 310/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7184
# Epoch 311/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.6417
# Epoch 312/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.2315
# Epoch 313/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8292
# Epoch 314/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.6216
# Epoch 315/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.1363
# Epoch 316/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8588
# Epoch 317/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8397
# Epoch 318/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.1719
# Epoch 319/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6815
# Epoch 320/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.0522
# Epoch 321/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.2437
# Epoch 322/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.3177
# Epoch 323/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.3034
# Epoch 324/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.2770
# Epoch 325/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8488
# Epoch 326/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6869
# Epoch 327/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.8775
# Epoch 328/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.9630
# Epoch 329/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5224
# Epoch 330/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0861
# Epoch 331/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.9545
# Epoch 332/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.1081
# Epoch 333/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7397
# Epoch 334/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.2390
# Epoch 335/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5206
# Epoch 336/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5606
# Epoch 337/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.7435
# Epoch 338/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8224
# Epoch 339/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.1365
# Epoch 340/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8137
# Epoch 341/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.7447
# Epoch 342/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0112
# Epoch 343/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.2303
# Epoch 344/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.6173
# Epoch 345/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0998
# Epoch 346/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0513
# Epoch 347/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.3709
# Epoch 348/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8676
# Epoch 349/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.8503
# Epoch 350/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.3415
# Epoch 351/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.0287
# Epoch 352/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7947
# Epoch 353/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.6859
# Epoch 354/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7825
# Epoch 355/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5774
# Epoch 356/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0687
# Epoch 357/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0809
# Epoch 358/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6649
# Epoch 359/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.1468
# Epoch 360/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.6069
# Epoch 361/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.1684
# Epoch 362/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.9762
# Epoch 363/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.5102
# Epoch 364/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6822
# Epoch 365/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.3269
# Epoch 366/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.1458
# Epoch 367/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.9874
# Epoch 368/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5723
# Epoch 369/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4909
# Epoch 370/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7060
# Epoch 371/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8854
# Epoch 372/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8921
# Epoch 373/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.2661
# Epoch 374/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5519
# Epoch 375/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.3648
# Epoch 376/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4275
# Epoch 377/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.9133
# Epoch 378/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.7421
# Epoch 379/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.8581
# Epoch 380/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.5080
# Epoch 381/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.3577
# Epoch 382/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.9523
# Epoch 383/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.5743
# Epoch 384/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5808
# Epoch 385/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8917
# Epoch 386/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.2530
# Epoch 387/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.1178
# Epoch 388/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8320
# Epoch 389/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.1290
# Epoch 390/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.6541
# Epoch 391/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.6466
# Epoch 392/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.9344
# Epoch 393/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0185
# Epoch 394/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4986
# Epoch 395/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.3751
# Epoch 396/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8846
# Epoch 397/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5279
# Epoch 398/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.9399
# Epoch 399/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6657
# Epoch 400/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8590
# Epoch 401/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8310
# Epoch 402/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.3435
# Epoch 403/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.0592
# Epoch 404/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.1953
# Epoch 405/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.3257
# Epoch 406/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0287
# Epoch 407/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4196
# Epoch 408/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.9584
# Epoch 409/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.8022
# Epoch 410/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.9650
# Epoch 411/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.0400
# Epoch 412/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.7160
# Epoch 413/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5943
# Epoch 414/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.9222
# Epoch 415/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.2774
# Epoch 416/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.1307
# Epoch 417/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.2283
# Epoch 418/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6117
# Epoch 419/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.5524
# Epoch 420/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.3441
# Epoch 421/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.2496
# Epoch 422/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4068
# Epoch 423/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7359
# Epoch 424/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.5715
# Epoch 425/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.5250
# Epoch 426/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.3096
# Epoch 427/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7234
# Epoch 428/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7255
# Epoch 429/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.3996
# Epoch 430/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.3408
# Epoch 431/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8544
# Epoch 432/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.2833
# Epoch 433/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0551
# Epoch 434/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.9467
# Epoch 435/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8084
# Epoch 436/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.2504
# Epoch 437/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.2938
# Epoch 438/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.8181
# Epoch 439/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7392
# Epoch 440/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8366
# Epoch 441/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5289
# Epoch 442/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6682
# Epoch 443/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.5076
# Epoch 444/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7410
# Epoch 445/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.9816
# Epoch 446/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8093
# Epoch 447/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.2704
# Epoch 448/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4807
# Epoch 449/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.1782
# Epoch 450/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.8820
# Epoch 451/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8803
# Epoch 452/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5808
# Epoch 453/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4309
# Epoch 454/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.9606
# Epoch 455/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7731
# Epoch 456/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0888
# Epoch 457/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7050
# Epoch 458/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.1247
# Epoch 459/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.1212
# Epoch 460/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6441
# Epoch 461/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.5029
# Epoch 462/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8351
# Epoch 463/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4804
# Epoch 464/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.3874
# Epoch 465/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5242
# Epoch 466/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.1855
# Epoch 467/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.4341
# Epoch 468/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.9604
# Epoch 469/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.3300
# Epoch 470/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7681
# Epoch 471/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7153
# Epoch 472/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.9819
# Epoch 473/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.4683
# Epoch 474/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6154
# Epoch 475/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.1774
# Epoch 476/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0091
# Epoch 477/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.2014
# Epoch 478/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.9612
# Epoch 479/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.0719
# Epoch 480/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7774
# Epoch 481/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4495
# Epoch 482/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7108
# Epoch 483/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.2507
# Epoch 484/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.3765
# Epoch 485/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0303
# Epoch 486/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4793
# Epoch 487/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4493
# Epoch 488/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.1247
# Epoch 489/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.5000
# Epoch 490/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6199
# Epoch 491/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.4457
# Epoch 492/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.1407
# Epoch 493/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4726
# Epoch 494/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.1926
# Epoch 495/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5342
# Epoch 496/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7362
# Epoch 497/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.2111
# Epoch 498/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.9732
# Epoch 499/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0116
# Epoch 500/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.1653
# Epoch 501/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0819
# Epoch 502/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.8276
# Epoch 503/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.3911
# Epoch 504/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7394
# Epoch 505/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6468
# Epoch 506/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5817
# Epoch 507/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6637
# Epoch 508/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.7855
# Epoch 509/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.1297
# Epoch 510/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6800
# Epoch 511/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4765
# Epoch 512/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0518
# Epoch 513/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7436
# Epoch 514/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5091
# Epoch 515/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5542
# Epoch 516/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.9896
# Epoch 517/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3573
# Epoch 518/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.1353
# Epoch 519/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.9371
# Epoch 520/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7833
# Epoch 521/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.1437
# Epoch 522/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6325
# Epoch 523/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.5074
# Epoch 524/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.5371
# Epoch 525/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.4607
# Epoch 526/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5824
# Epoch 527/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.1123
# Epoch 528/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7824
# Epoch 529/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5673
# Epoch 530/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5343
# Epoch 531/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8472
# Epoch 532/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4317
# Epoch 533/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8451
# Epoch 534/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.3538
# Epoch 535/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8211
# Epoch 536/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.9262
# Epoch 537/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7333
# Epoch 538/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.9393
# Epoch 539/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0650
# Epoch 540/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.9311
# Epoch 541/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.2395
# Epoch 542/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6380
# Epoch 543/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6283
# Epoch 544/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.9120
# Epoch 545/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6631
# Epoch 546/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8307
# Epoch 547/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5746
# Epoch 548/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5297
# Epoch 549/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8303
# Epoch 550/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.6941
# Epoch 551/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.3554
# Epoch 552/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8256
# Epoch 553/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.6236
# Epoch 554/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.1144
# Epoch 555/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0526
# Epoch 556/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5197
# Epoch 557/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.3579
# Epoch 558/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4290
# Epoch 559/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4803
# Epoch 560/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7580
# Epoch 561/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4718
# Epoch 562/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.9659
# Epoch 563/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.4714
# Epoch 564/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5893
# Epoch 565/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.2547
# Epoch 566/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4115
# Epoch 567/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.9412
# Epoch 568/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0270
# Epoch 569/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5074
# Epoch 570/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.6937
# Epoch 571/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6177
# Epoch 572/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.1629
# Epoch 573/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8686
# Epoch 574/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.9836
# Epoch 575/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5332
# Epoch 576/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.3873
# Epoch 577/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8489
# Epoch 578/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6447
# Epoch 579/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.1297
# Epoch 580/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.1007
# Epoch 581/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8524
# Epoch 582/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8418
# Epoch 583/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0290
# Epoch 584/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.3222
# Epoch 585/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6534
# Epoch 586/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.3352
# Epoch 587/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.9740
# Epoch 588/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5847
# Epoch 589/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.2297
# Epoch 590/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.1473
# Epoch 591/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0945
# Epoch 592/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.3819
# Epoch 593/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7421
# Epoch 594/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6198
# Epoch 595/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.3644
# Epoch 596/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.8005
# Epoch 597/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.9310
# Epoch 598/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.3487
# Epoch 599/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8095
# Epoch 600/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5007
# Epoch 601/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.3447
# Epoch 602/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3876
# Epoch 603/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.0929
# Epoch 604/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6552
# Epoch 605/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.1410
# Epoch 606/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.3068
# Epoch 607/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.0886
# Epoch 608/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.8938
# Epoch 609/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6051
# Epoch 610/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.2840
# Epoch 611/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.3936
# Epoch 612/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.3093
# Epoch 613/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7744
# Epoch 614/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4548
# Epoch 615/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.1325
# Epoch 616/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6350
# Epoch 617/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.2903
# Epoch 618/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7255
# Epoch 619/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.9537
# Epoch 620/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.3488
# Epoch 621/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7591
# Epoch 622/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4190
# Epoch 623/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.2333
# Epoch 624/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.9853
# Epoch 625/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.1178
# Epoch 626/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.3449
# Epoch 627/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.7960
# Epoch 628/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6584
# Epoch 629/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5191
# Epoch 630/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.9888
# Epoch 631/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.2625
# Epoch 632/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.9783
# Epoch 633/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.1269
# Epoch 634/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.0879
# Epoch 635/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.2173
# Epoch 636/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.3784
# Epoch 637/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3725
# Epoch 638/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6327
# Epoch 639/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6451
# Epoch 640/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.1678
# Epoch 641/1000
# ...
# Epoch 770/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4859
# Epoch 771/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0306
# Epoch 772/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.1973
# Epoch 773/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2936
# Epoch 774/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.3267
# Epoch 775/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7172
# Epoch 776/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4244
# Epoch 777/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.2311
# Epoch 778/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.9844
# Epoch 779/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.5177
# Epoch 780/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0904
# Epoch 781/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.3212
# Epoch 782/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4406
# Epoch 783/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.1958
# Epoch 784/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5457
# Epoch 785/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7201
# Epoch 786/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5219
# Epoch 787/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8663
# Epoch 788/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.2037
# Epoch 789/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.3580
# Epoch 790/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.0524
# Epoch 791/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.3040
# Epoch 792/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6775
# Epoch 793/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5080
# Epoch 794/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5410
# Epoch 795/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5244
# Epoch 796/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.9111
# Epoch 797/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4760
# Epoch 798/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1810
# Epoch 799/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5795
# Epoch 800/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5153
# Epoch 801/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6417
# Epoch 802/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6694
# Epoch 803/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7020
# Epoch 804/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4226
# Epoch 805/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3116
# Epoch 806/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.3788
# Epoch 807/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0598
# Epoch 808/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.1517
# Epoch 809/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5105
# Epoch 810/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8941
# Epoch 811/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4480
# Epoch 812/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.3600
# Epoch 813/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4022
# Epoch 814/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0060
# Epoch 815/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4913
# Epoch 816/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.1264
# Epoch 817/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7538
# Epoch 818/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.9844
# Epoch 819/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5184
# Epoch 820/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0000
# Epoch 821/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8742
# Epoch 822/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.3358
# Epoch 823/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1939
# Epoch 824/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.9738
# Epoch 825/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5553
# Epoch 826/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4108
# Epoch 827/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7630
# Epoch 828/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4527
# Epoch 829/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.3540
# Epoch 830/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3452
# Epoch 831/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7082
# Epoch 832/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.6026
# Epoch 833/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7851
# Epoch 834/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.8382
# Epoch 835/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4573
# Epoch 836/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5204
# Epoch 837/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.3374
# Epoch 838/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.8239
# Epoch 839/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.2076
# Epoch 840/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.9762
# Epoch 841/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.9235
# Epoch 842/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7037
# Epoch 843/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.3554
# Epoch 844/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8920
# Epoch 845/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5412
# Epoch 846/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.9981
# Epoch 847/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.1918
# Epoch 848/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5930
# Epoch 849/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5366
# Epoch 850/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4600
# Epoch 851/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5069
# Epoch 852/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6151
# Epoch 853/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4571
# Epoch 854/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8150
# Epoch 855/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.9039
# Epoch 856/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4118
# Epoch 857/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7314
# Epoch 858/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5917
# Epoch 859/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.2928
# Epoch 860/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.4951
# Epoch 861/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.0732
# Epoch 862/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3856
# Epoch 863/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0422
# Epoch 864/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7096
# Epoch 865/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5771
# Epoch 866/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.2443
# Epoch 867/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6407
# Epoch 868/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0891
# Epoch 869/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7923
# Epoch 870/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.2547
# Epoch 871/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.0521
# Epoch 872/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8237
# Epoch 873/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.1986
# Epoch 874/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.3379
# Epoch 875/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.9401
# Epoch 876/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5374
# Epoch 877/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5013
# Epoch 878/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4855
# Epoch 879/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5334
# Epoch 880/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4942
# Epoch 881/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.3712
# Epoch 882/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6549
# Epoch 883/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.9126
# Epoch 884/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6204
# Epoch 885/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.9746
# Epoch 886/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.1969
# Epoch 887/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7731
# Epoch 888/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.7953
# Epoch 889/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5732
# Epoch 890/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5682
# Epoch 891/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7957
# Epoch 892/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5019
# Epoch 893/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8902
# Epoch 894/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6533
# Epoch 895/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7381
# Epoch 896/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.2875
# Epoch 897/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6251
# Epoch 898/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.2653
# Epoch 899/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.1386
# Epoch 900/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.1383
# Epoch 901/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7580
# Epoch 902/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4199
# Epoch 903/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.3044
# Epoch 904/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5740
# Epoch 905/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.1270
# Epoch 906/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8231
# Epoch 907/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7717
# Epoch 908/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.2430
# Epoch 909/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5505
# Epoch 910/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5258
# Epoch 911/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5186
# Epoch 912/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4757
# Epoch 913/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7205
# Epoch 914/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4023
# Epoch 915/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.8918
# Epoch 916/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4489
# Epoch 917/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.9160
# Epoch 918/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6851
# Epoch 919/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0076
# Epoch 920/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.0524
# Epoch 921/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0213
# Epoch 922/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0460
# Epoch 923/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.9480
# Epoch 924/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.7289
# Epoch 925/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.9337
# Epoch 926/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7346
# Epoch 927/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6414
# Epoch 928/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7743
# Epoch 929/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.8774
# Epoch 930/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4983
# Epoch 931/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.3372
# Epoch 932/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.9858
# Epoch 933/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.2917
# Epoch 934/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.0397
# Epoch 935/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6566
# Epoch 936/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4716
# Epoch 937/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.3881
# Epoch 938/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.2370
# Epoch 939/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.2444
# Epoch 940/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4987
# Epoch 941/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.3570
# Epoch 942/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7045
# Epoch 943/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.2614
# Epoch 944/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.9441
# Epoch 945/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.3209
# Epoch 946/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.2465
# Epoch 947/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5071
# Epoch 948/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.1792
# Epoch 949/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.3085
# Epoch 950/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8737
# Epoch 951/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.1681
# Epoch 952/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7137
# Epoch 953/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4421
# Epoch 954/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7117
# Epoch 955/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5543
# Epoch 956/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.3876
# Epoch 957/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1160
# Epoch 958/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.3783
# Epoch 959/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.4453
# Epoch 960/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7546
# Epoch 961/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.1482
# Epoch 962/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0077
# Epoch 963/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.1442
# Epoch 964/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2404
# Epoch 965/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5219
# Epoch 966/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8558
# Epoch 967/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4466
# Epoch 968/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6183
# Epoch 969/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6972
# Epoch 970/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.0659
# Epoch 971/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4184
# Epoch 972/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5330
# Epoch 973/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.0048
# Epoch 974/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.3519
# Epoch 975/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0509
# Epoch 976/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.1456
# Epoch 977/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1060
# Epoch 978/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.9056
# Epoch 979/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.3363
# Epoch 980/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6873
# Epoch 981/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4796
# Epoch 982/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8192
# Epoch 983/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.7262
# Epoch 984/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5258
# Epoch 985/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5374
# Epoch 986/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.0203
# Epoch 987/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.7170
# Epoch 988/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.2371
# Epoch 989/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.2161
# Epoch 990/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.7072
# Epoch 991/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6159
# Epoch 992/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.5167
# Epoch 993/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5022
# Epoch 994/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.0833
# Epoch 995/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4392
# Epoch 996/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.7785
# Epoch 997/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.3616
# Epoch 998/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4442
# Epoch 999/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5069
# Epoch 1000/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4721
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 758us/step - loss: 3.9361

# %%
stocks = ["AAPL", "MSFT", "GOOGL", "AMZN", "META", "NVDA", "TSLA"]

for stock in stocks:
    predicting_data = pd.read_csv(f"processed_stock_data/{stock}_processed.csv")
    predicting_data = predicting_data.tail(20)
    predicting_data.to_csv(f"/Users/noel_personal/Repos/TIKR/my-react-app/backend/predicting_data/{stock}.csv",index=False)

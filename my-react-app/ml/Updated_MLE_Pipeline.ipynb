# %%
import os
import yfinance as yf
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, LSTM
import joblib

def download_and_clean_stock_data(stock):
    """
    Download stock data for the Magnificent Seven, clean it, and save as CSV files.
    """
   
    output_dir = "raw_stock_data"
    os.makedirs(output_dir, exist_ok=True)

    def save_cleaned_data(data, stock, output_path):
        # Reset index to turn the Date index into a column
        data.reset_index(inplace=True)
        # Retain only the desired columns
        data = data[["Date", "Open", "High", "Low", "Close", "Volume"]]
        # Add a Ticker column
        data["Ticker"] = stock
        # Save the data to CSV
        data.to_csv(output_path, index=False)
        # Reload and remove the first row (if needed)
        data = pd.read_csv(output_path)
        data = data.iloc[1:]
        data.to_csv(output_path, index=False)

    for stock in stocks:
        data = yf.download(stock, start="2015-01-01", end="2025-01-01")
        output_path = os.path.join(output_dir, f"{stock}.csv")
        save_cleaned_data(data, stock, output_path)
        # print(f"Saved cleaned data for {stock} at {output_path}")

def preprocess_data(stock):
    """
    Preprocess each stock's data by converting dates, sorting, and adding new features.
    The processed CSV files are saved into a separate folder.
    """
    data_dir = "raw_stock_data"
    output_dir = "processed_stock_data"
    os.makedirs(output_dir, exist_ok=True)

    def preprocess_stock_data(file_path):
        data = pd.read_csv(file_path)
        # Convert Date to datetime and sort
        data["Date"] = pd.to_datetime(data["Date"])
        data.sort_values(by="Date", inplace=True)
        # Calculate additional features
        data["Daily Return"] = data["Close"].pct_change()
        data["5-Day Moving Avg"] = data["Close"].rolling(window=5).mean()
        data["10-Day Volatility"] = data["Close"].rolling(window=10).std()
        # Remove rows with NaN values from rolling calculations
        data.dropna(inplace=True)
        return data

    for file_name in os.listdir(data_dir):
        if file_name.endswith(".csv"):
            stock_file_path = os.path.join(data_dir, file_name)
            stock_name = os.path.splitext(file_name)[0]
            # print(f"Processing data for {stock_name}...")
            processed_data = preprocess_stock_data(stock_file_path)
            output_path = os.path.join(output_dir, f"{stock_name}_processed.csv")
            processed_data.to_csv(output_path, index=False)
            # print(f"Saved processed data for {stock_name} to {output_path}")
    # print("Data preprocessing complete!")

def load_stock_data(file_path):
    """
    Load processed data from a CSV file and prepare features and target.
    The target is the next day's closing price.
    """
    data = pd.read_csv(file_path)
    features = data[["Open", "High", "Low", "Close", "Volume", "5-Day Moving Avg", "10-Day Volatility"]]
    target = data["Close"].shift(-1)
    # Drop the last row (where target is NaN)
    features = features[:-1]
    target = target[:-1]
    return features, target

def train_model(ticker):
    """
    Load the AAPL processed data, split into training and testing sets,
    build and train a neural network with LSTM layers, and save the model.
    """
    processed_data_dir = "processed_stock_data"
    stock_file_path = os.path.join(processed_data_dir, f"{ticker}_processed.csv")
    features, target = load_stock_data(stock_file_path)

    # Split the data into training and testing sets
    X_train, X_test, y_train, y_test = train_test_split(
        features.values, target.values, test_size=0.2, random_state=42
    )

    # Reshape data for LSTM: (samples, timesteps, features)
    X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
    X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

    # Build the LSTM model
    model = Sequential()
    model.add(LSTM(50, return_sequences=True, input_shape=(X_train.shape[1], 1)))
    model.add(LSTM(50))
    model.add(Dense(1))
    model.compile(optimizer="adam", loss="mean_squared_error")

    # print("Training the model...")
    model.fit(X_train, y_train, epochs=1000, batch_size=32, verbose=1)

    # print("Evaluating the model on the test set...")
    loss = model.evaluate(X_test, y_test)
    # print(f"Test Loss: {loss}")

    # Save the trained model
    joblib.dump(model,f"models/{ticker}_model.joblib")
    # model.save("models/AAPL_model.h5")
    # print("Model saved as 'models/AAPL_model.h5'")

def evaluate_model():
    """
    Evaluate the saved model on a portion of AAPL's data and # print error metrics.
    Also, predict the next few days' closing prices and save these predictions to CSV.
    """
    processed_data_dir = "processed_stock_data"
    model_path = "stock_price_predictor.h5"
    model = load_model(model_path)

    def load_evaluation_data(file_path):
        data = pd.read_csv(file_path)
        features = data[["Open", "High", "Low", "Close", "Volume", "5-Day Moving Avg", "10-Day Volatility"]]
        target = data["Close"].shift(-1)
        features = features[:-1]
        target = target[:-1]
        # Use the last 10 rows for evaluation (e.g., next days' predictions)
        evaluation_features = features[-10:]
        evaluation_target = target[-10:]
        # Remove the evaluation portion from the main dataset
        features = features[:-10]
        target = target[:-10]
        return features, target, evaluation_features, evaluation_target

    stock_file_path = os.path.join(processed_data_dir, "AAPL_processed.csv")
    features, target, eval_features, eval_target = load_evaluation_data(stock_file_path)

    # Reshape data for LSTM input
    X_train = np.reshape(features.values, (features.shape[0], features.shape[1], 1))
    X_eval = np.reshape(eval_features.values, (eval_features.shape[0], eval_features.shape[1], 1))

    # Evaluate on the training portion (without the last few evaluation rows)
    predicted_train = model.predict(X_train)
    mse = mean_squared_error(target, predicted_train)
    mae = mean_absolute_error(target, predicted_train)
    r2 = r2_score(target, predicted_train)
    
    # print("### Model Evaluation on Training Data ###")
    # print(f"Mean Squared Error (MSE): {mse:.4f}")
    # print(f"Mean Absolute Error (MAE): {mae:.4f}")
    # print(f"R-squared (R2): {r2:.4f}")

    # Predict the next days' prices using the evaluation features
    predicted_eval = model.predict(X_eval)
    results = pd.DataFrame({
        "Index": eval_features.index,
        "Actual Price": eval_target.values,
        "Predicted Price": predicted_eval.flatten()
    })

    # print("### Next Days' Predictions ###")
    # print(results)

    # Save predictions to a CSV file
    # results.to_csv("next_month_predictions.csv", index=False)
    # print("Predictions saved as 'next_month_predictions.csv'")

def main(ticker):
    # print("Starting the stock data pipeline...")
    download_and_clean_stock_data(ticker)
    preprocess_data(ticker)
    train_model(ticker)
    # evaluate_model()
    # print("Pipeline complete!")


for ticker in ["AAPL", "MSFT", "GOOGL", "AMZN", "META", "NVDA", "TSLA"]:
    main(ticker)
# Out:
# [*********************100%***********************]  1 of 1 completed
# /var/folders/s_/kpvlk3bs5v7_vx6qt436qn400000gn/T/ipykernel_20558/1277189767.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Ticker"] = stock
# [*********************100%***********************]  1 of 1 completed
# /var/folders/s_/kpvlk3bs5v7_vx6qt436qn400000gn/T/ipykernel_20558/1277189767.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Ticker"] = stock
# [*********************100%***********************]  1 of 1 completed
# /var/folders/s_/kpvlk3bs5v7_vx6qt436qn400000gn/T/ipykernel_20558/1277189767.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Ticker"] = stock
# [*********************100%***********************]  1 of 1 completed
# /var/folders/s_/kpvlk3bs5v7_vx6qt436qn400000gn/T/ipykernel_20558/1277189767.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Ticker"] = stock
# [*********************100%***********************]  1 of 1 completed
# /var/folders/s_/kpvlk3bs5v7_vx6qt436qn400000gn/T/ipykernel_20558/1277189767.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Ticker"] = stock
# [*********************100%***********************]  1 of 1 completed
# /var/folders/s_/kpvlk3bs5v7_vx6qt436qn400000gn/T/ipykernel_20558/1277189767.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Ticker"] = stock
# [*********************100%***********************]  1 of 1 completed
# /var/folders/s_/kpvlk3bs5v7_vx6qt436qn400000gn/T/ipykernel_20558/1277189767.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Ticker"] = stock
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 12643.4326
# Epoch 2/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 10722.3262
# Epoch 3/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 10446.5098
# Epoch 4/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9651.2930
# Epoch 5/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9742.2588
# Epoch 6/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8992.3408
# Epoch 7/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9080.9004
# Epoch 8/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8505.6045
# Epoch 9/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7902.9692
# Epoch 10/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7456.9067
# Epoch 11/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7261.1982
# Epoch 12/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7037.8032
# Epoch 13/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6827.2578
# Epoch 14/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6341.6689
# Epoch 15/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6280.8457
# Epoch 16/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5925.9932
# Epoch 17/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5820.9438
# Epoch 18/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5712.6753
# Epoch 19/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5455.4346
# Epoch 20/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5216.6372
# Epoch 21/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5542.3721
# Epoch 22/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5147.5557
# Epoch 23/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4857.5596
# Epoch 24/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4653.1567
# Epoch 25/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3966.5872
# Epoch 26/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4088.3533
# Epoch 27/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3783.3145
# Epoch 28/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3731.5640
# Epoch 29/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3515.5991
# Epoch 30/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3217.0576
# Epoch 31/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3001.1487
# Epoch 32/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3061.2949
# Epoch 33/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2765.9780
# Epoch 34/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2650.5542
# Epoch 35/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2646.9592
# Epoch 36/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2408.6094
# Epoch 37/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2244.4729
# Epoch 38/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2232.9885
# Epoch 39/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1928.0405
# Epoch 40/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1974.4948
# Epoch 41/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1864.3818
# Epoch 42/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1665.0065
# Epoch 43/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1463.1705
# Epoch 44/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1487.8407
# Epoch 45/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1377.0785
# Epoch 46/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1354.7958
# Epoch 47/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1161.3168
# Epoch 48/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1237.4899
# Epoch 49/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1236.6571
# Epoch 50/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1229.6194
# Epoch 51/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1051.0176
# Epoch 52/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 982.0803
# Epoch 53/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 941.9893
# Epoch 54/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 837.3033
# Epoch 55/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 753.8121
# Epoch 56/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 732.8074
# Epoch 57/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 765.5467
# Epoch 58/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 700.9900
# Epoch 59/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 685.0516
# Epoch 60/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 613.1119
# Epoch 61/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 567.5196
# Epoch 62/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 593.8420
# Epoch 63/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 516.9925
# Epoch 64/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 544.8643
# Epoch 65/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 491.3265
# Epoch 66/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 475.5612
# Epoch 67/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 468.3509
# Epoch 68/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 420.3638
# Epoch 69/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 398.2588
# Epoch 70/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 379.7556
# Epoch 71/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 423.7196
# Epoch 72/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 333.5006
# Epoch 73/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 300.2516
# Epoch 74/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 276.9100
# Epoch 75/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 297.9963
# Epoch 76/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 325.3478
# Epoch 77/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 271.3218
# Epoch 78/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 254.7537
# Epoch 79/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 273.3178
# Epoch 80/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 263.5254
# Epoch 81/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 236.3065
# Epoch 82/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 216.8591
# Epoch 83/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 245.5217
# Epoch 84/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 180.0178
# Epoch 85/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 211.5399
# Epoch 86/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 197.2030
# Epoch 87/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 184.3928
# Epoch 88/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 183.1447
# Epoch 89/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 142.6740
# Epoch 90/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 162.2286
# Epoch 91/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 154.9360
# Epoch 92/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 139.5168
# Epoch 93/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 126.8083
# Epoch 94/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 139.6095
# Epoch 95/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 119.5899
# Epoch 96/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 110.6706
# Epoch 97/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 152.8608
# Epoch 98/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 112.6055
# Epoch 99/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 102.2030
# Epoch 100/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 98.0296
# Epoch 101/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 93.6193
# Epoch 102/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 87.1178
# Epoch 103/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 91.7262
# Epoch 104/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 82.5809
# Epoch 105/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 75.7454
# Epoch 106/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 69.7845
# Epoch 107/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 77.6418
# Epoch 108/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 78.0746
# Epoch 109/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 63.5243
# Epoch 110/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 61.4154
# Epoch 111/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 67.7675
# Epoch 112/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 69.2733
# Epoch 113/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 62.5306
# Epoch 114/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 53.3505
# Epoch 115/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 53.5364
# Epoch 116/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 54.0994
# Epoch 117/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 38.2998
# Epoch 118/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 49.4127
# Epoch 119/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 46.6131
# Epoch 120/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 36.7654
# Epoch 121/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 35.4796
# Epoch 122/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 35.3609
# Epoch 123/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 35.6374
# Epoch 124/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 30.6120
# Epoch 125/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 28.4689
# Epoch 126/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 27.3586
# Epoch 127/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 31.6090
# Epoch 128/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 31.3491
# Epoch 129/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 24.7827
# Epoch 130/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 24.7553
# Epoch 131/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 25.9384
# Epoch 132/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 20.4008
# Epoch 133/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 18.8478
# Epoch 134/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 19.1582
# Epoch 135/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 22.3474
# Epoch 136/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 18.7306
# Epoch 137/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 19.4256
# Epoch 138/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 15.0064
# Epoch 139/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 14.8453
# Epoch 140/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 18.3792
# Epoch 141/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 16.3634
# Epoch 142/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 15.2686
# Epoch 143/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 14.1697
# Epoch 144/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 13.1349
# Epoch 145/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 10.7647
# Epoch 146/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 11.7811
# Epoch 147/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 12.7716
# Epoch 148/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 14.2868
# Epoch 149/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 12.7576
# Epoch 150/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.6328
# Epoch 151/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 10.1865
# Epoch 152/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 10.2893
# Epoch 153/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 10.0476
# Epoch 154/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 10.7016
# Epoch 155/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.7117
# Epoch 156/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 12.0420
# Epoch 157/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 11.4784
# Epoch 158/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.8215
# Epoch 159/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 11.0829
# Epoch 160/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.9190
# Epoch 161/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 10.3857
# Epoch 162/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.3456
# Epoch 163/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.4078
# Epoch 164/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.7459
# Epoch 165/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.0072
# Epoch 166/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.3111
# Epoch 167/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.5877
# Epoch 168/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.3697
# Epoch 169/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.7527
# Epoch 170/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.2998
# Epoch 171/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.7511
# Epoch 172/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.9804
# Epoch 173/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.2099
# Epoch 174/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.9618
# Epoch 175/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.0496
# Epoch 176/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.2182
# Epoch 177/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.8232
# Epoch 178/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.3620
# Epoch 179/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.0264
# Epoch 180/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.2208
# Epoch 181/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.0760
# Epoch 182/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.0222
# Epoch 183/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.6484
# Epoch 184/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.7147
# Epoch 185/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.3145
# Epoch 186/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.4399
# Epoch 187/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.1843
# Epoch 188/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.1520
# Epoch 189/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.3051
# Epoch 190/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.0007
# Epoch 191/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.8474
# Epoch 192/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.7886
# Epoch 193/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.4442
# Epoch 194/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.5904
# Epoch 195/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.0924
# Epoch 196/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.7861
# Epoch 197/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.4668
# Epoch 198/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.6476
# Epoch 199/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.6814
# Epoch 200/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.0804
# Epoch 201/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.6566
# Epoch 202/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.1306
# Epoch 203/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.3645
# Epoch 204/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.6320
# Epoch 205/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.1384
# Epoch 206/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.2425
# Epoch 207/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.3588
# Epoch 208/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.8352
# Epoch 209/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.9997
# Epoch 210/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.9327
# Epoch 211/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0736
# Epoch 212/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.2773
# Epoch 213/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.5134
# Epoch 214/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.4491
# Epoch 215/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.0323
# Epoch 216/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.3429
# Epoch 217/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.3519
# Epoch 218/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.7690
# Epoch 219/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.1572
# Epoch 220/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.2171
# Epoch 221/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.9541
# Epoch 222/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.6090
# Epoch 223/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.8429
# Epoch 224/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.9915
# Epoch 225/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.1266
# Epoch 226/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.1163
# Epoch 227/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.3599
# Epoch 228/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.1421
# Epoch 229/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.9312
# Epoch 230/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.1637
# Epoch 231/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.0891
# Epoch 232/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.2347
# Epoch 233/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.0066
# Epoch 234/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.9544
# Epoch 235/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.9713
# Epoch 236/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.7918
# Epoch 237/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.7560
# Epoch 238/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.1032
# Epoch 239/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.4176
# Epoch 240/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.1591
# Epoch 241/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.4306
# Epoch 242/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.3854
# Epoch 243/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7959
# Epoch 244/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.4937
# Epoch 245/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.5986
# Epoch 246/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.9465
# Epoch 247/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.3702
# Epoch 248/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.8500
# Epoch 249/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.1724
# Epoch 250/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.2007
# Epoch 251/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.3348
# Epoch 252/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.6365
# Epoch 253/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.9697
# Epoch 254/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.0600
# Epoch 255/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.2610
# Epoch 256/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8830
# Epoch 257/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.9945
# Epoch 258/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.4679
# Epoch 259/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.8899
# Epoch 260/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.3918
# Epoch 261/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.0446
# Epoch 262/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.4033
# Epoch 263/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.2225
# Epoch 264/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.3962
# Epoch 265/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.4514
# Epoch 266/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.4115
# Epoch 267/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.9930
# Epoch 268/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.3762
# Epoch 269/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.2903
# Epoch 270/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.2066
# Epoch 271/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.8701
# Epoch 272/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6773
# Epoch 273/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.9655
# Epoch 274/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.5916
# Epoch 275/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.3217
# Epoch 276/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.9937
# Epoch 277/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.1319
# Epoch 278/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.6911
# Epoch 279/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.2480
# Epoch 280/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.6432
# Epoch 281/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.1390
# Epoch 282/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5926
# Epoch 283/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.4174
# Epoch 284/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.1665
# Epoch 285/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5564
# Epoch 286/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8286
# Epoch 287/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.6757
# Epoch 288/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.4337
# Epoch 289/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.2693
# Epoch 290/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0560
# Epoch 291/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.9226
# Epoch 292/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.0652
# Epoch 293/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.1068
# Epoch 294/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.4013
# Epoch 295/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.3776
# Epoch 296/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.3260
# Epoch 297/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.5933
# Epoch 298/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.6209
# Epoch 299/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.1662
# Epoch 300/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0883
# Epoch 301/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0150
# Epoch 302/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.3222
# Epoch 303/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8796
# Epoch 304/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.1907
# Epoch 305/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.9952
# Epoch 306/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.5760
# Epoch 307/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.2706
# Epoch 308/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.8767
# Epoch 309/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.7427
# Epoch 310/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0166
# Epoch 311/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.2844
# Epoch 312/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.3916
# Epoch 313/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.1989
# Epoch 314/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.2551
# Epoch 315/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5976
# Epoch 316/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.2001
# Epoch 317/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.2209
# Epoch 318/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.1603
# Epoch 319/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.5619
# Epoch 320/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0748
# Epoch 321/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.3384
# Epoch 322/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8110
# Epoch 323/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.5672
# Epoch 324/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.1549
# Epoch 325/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.2598
# Epoch 326/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.4416
# Epoch 327/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.1252
# Epoch 328/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.3836
# Epoch 329/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.2040
# Epoch 330/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.0948
# Epoch 331/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.9536
# Epoch 332/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8939
# Epoch 333/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6388
# Epoch 334/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.2246
# Epoch 335/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.4847
# Epoch 336/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.2655
# Epoch 337/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.4095
# Epoch 338/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.1273
# Epoch 339/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6742
# Epoch 340/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.3434
# Epoch 341/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5050
# Epoch 342/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.5509
# Epoch 343/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.4590
# Epoch 344/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8007
# Epoch 345/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.8820
# Epoch 346/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0688
# Epoch 347/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0460
# Epoch 348/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.5327
# Epoch 349/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.0565
# Epoch 350/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0329
# Epoch 351/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.6436
# Epoch 352/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.3717
# Epoch 353/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5049
# Epoch 354/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.9058
# Epoch 355/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.7050
# Epoch 356/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.5080
# Epoch 357/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.2385
# Epoch 358/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.1697
# Epoch 359/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.3810
# Epoch 360/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0637
# Epoch 361/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.3853
# Epoch 362/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.3396
# Epoch 363/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4318
# Epoch 364/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0466
# Epoch 365/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.5139
# Epoch 366/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.5965
# Epoch 367/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.3146
# Epoch 368/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.1745
# Epoch 369/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.6132
# Epoch 370/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8894
# Epoch 371/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.9290
# Epoch 372/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6731
# Epoch 373/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6945
# Epoch 374/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.2959
# Epoch 375/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.1386
# Epoch 376/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.9150
# Epoch 377/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7336
# Epoch 378/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8602
# Epoch 379/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0015
# Epoch 380/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.4837
# Epoch 381/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5898
# Epoch 382/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.1029
# Epoch 383/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.7219
# Epoch 384/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.4585
# Epoch 385/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6165
# Epoch 386/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.4617
# Epoch 387/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.5988
# Epoch 388/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.5240
# Epoch 389/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0738
# Epoch 390/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.7050
# Epoch 391/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.2187
# Epoch 392/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5108
# Epoch 393/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.3565
# Epoch 394/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.6787
# Epoch 395/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6963
# Epoch 396/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.3711
# Epoch 397/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.1652
# Epoch 398/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8579
# Epoch 399/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5236
# Epoch 400/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8816
# Epoch 401/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.2552
# Epoch 402/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5797
# Epoch 403/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7720
# Epoch 404/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.1804
# Epoch 405/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5846
# Epoch 406/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.0849
# Epoch 407/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7337
# Epoch 408/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.5176
# Epoch 409/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5462
# Epoch 410/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4372
# Epoch 411/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.1221
# Epoch 412/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.1789
# Epoch 413/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.0196
# Epoch 414/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0508
# Epoch 415/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5106
# Epoch 416/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8262
# Epoch 417/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4326
# Epoch 418/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.8849
# Epoch 419/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0010
# Epoch 420/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7046
# Epoch 421/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.1525
# Epoch 422/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0318
# Epoch 423/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.9738
# Epoch 424/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.9600
# Epoch 425/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.9269
# Epoch 426/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8091
# Epoch 427/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.5252
# Epoch 428/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.7891
# Epoch 429/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.4244
# Epoch 430/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.7148
# Epoch 431/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4516
# Epoch 432/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.2020
# Epoch 433/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0589
# Epoch 434/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6848
# Epoch 435/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8019
# Epoch 436/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.4336
# Epoch 437/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6940
# Epoch 438/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7654
# Epoch 439/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6236
# Epoch 440/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4853
# Epoch 441/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5209
# Epoch 442/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.7767
# Epoch 443/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7173
# Epoch 444/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.7620
# Epoch 445/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0067
# Epoch 446/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4818
# Epoch 447/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8839
# Epoch 448/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.7894
# Epoch 449/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8263
# Epoch 450/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0547
# Epoch 451/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8171
# Epoch 452/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5400
# Epoch 453/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.7897
# Epoch 454/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.0638
# Epoch 455/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.8418
# Epoch 456/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.1529
# Epoch 457/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1222
# Epoch 458/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.2404
# Epoch 459/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.2767
# Epoch 460/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.1535
# Epoch 461/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.2614
# Epoch 462/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.7123
# Epoch 463/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8646
# Epoch 464/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.7461
# Epoch 465/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8459
# Epoch 466/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5166
# Epoch 467/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.1377
# Epoch 468/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8470
# Epoch 469/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.9778
# Epoch 470/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5828
# Epoch 471/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5925
# Epoch 472/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.6926
# Epoch 473/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.6134
# Epoch 474/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.2863
# Epoch 475/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.8416
# Epoch 476/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6538
# Epoch 477/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.3290
# Epoch 478/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5755
# Epoch 479/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6340
# Epoch 480/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8225
# Epoch 481/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.3812
# Epoch 482/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8292
# Epoch 483/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.5224
# Epoch 484/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.9407
# Epoch 485/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8180
# Epoch 486/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6536
# Epoch 487/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.1055
# Epoch 488/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0385
# Epoch 489/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.3511
# Epoch 490/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.2777
# Epoch 491/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.9107
# Epoch 492/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7360
# Epoch 493/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8494
# Epoch 494/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.2529
# Epoch 495/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.0761
# Epoch 496/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6009
# Epoch 497/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7873
# Epoch 498/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.4869
# Epoch 499/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6185
# Epoch 500/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.9265
# Epoch 501/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4298
# Epoch 502/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.3718
# Epoch 503/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8362
# Epoch 504/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4406
# Epoch 505/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7120
# Epoch 506/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.1164
# Epoch 507/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.5539
# Epoch 508/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8505
# Epoch 509/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.2086
# Epoch 510/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6099
# Epoch 511/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.9676
# Epoch 512/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.2613
# Epoch 513/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4764
# Epoch 514/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4690
# Epoch 515/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5365
# Epoch 516/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.3616
# Epoch 517/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8692
# Epoch 518/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.7015
# Epoch 519/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.0190
# Epoch 520/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6978
# Epoch 521/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8803
# Epoch 522/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7301
# Epoch 523/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8483
# Epoch 524/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.1811
# Epoch 525/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5462
# Epoch 526/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.1929
# Epoch 527/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4991
# Epoch 528/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.9759
# Epoch 529/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7322
# Epoch 530/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.2520
# Epoch 531/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.6119
# Epoch 532/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.0377
# Epoch 533/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6781
# Epoch 534/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.9172
# Epoch 535/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.2008
# Epoch 536/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.4199
# Epoch 537/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1273
# Epoch 538/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4661
# Epoch 539/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.7933
# Epoch 540/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4266
# Epoch 541/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6339
# Epoch 542/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7410
# Epoch 543/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8783
# Epoch 544/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.4025
# Epoch 545/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.3354
# Epoch 546/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.3530
# Epoch 547/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.0349
# Epoch 548/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6603
# Epoch 549/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.2297
# Epoch 550/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5298
# Epoch 551/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.5609
# Epoch 552/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6669
# Epoch 553/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.2014
# Epoch 554/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6653
# Epoch 555/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5775
# Epoch 556/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3995
# Epoch 557/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.1739
# Epoch 558/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8054
# Epoch 559/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.9914
# Epoch 560/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.2401
# Epoch 561/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.1779
# Epoch 562/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7117
# Epoch 563/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.1475
# Epoch 564/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.9297
# Epoch 565/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.1587
# Epoch 566/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.3708
# Epoch 567/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.6802
# Epoch 568/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1021
# Epoch 569/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8822
# Epoch 570/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.3877
# Epoch 571/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5320
# Epoch 572/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.9092
# Epoch 573/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.3090
# Epoch 574/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7156
# Epoch 575/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6363
# Epoch 576/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4992
# Epoch 577/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.9896
# Epoch 578/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8398
# Epoch 579/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6509
# Epoch 580/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3307
# Epoch 581/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.1301
# Epoch 582/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.0791
# Epoch 583/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.8873
# Epoch 584/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5179
# Epoch 585/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.2185
# Epoch 586/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5016
# Epoch 587/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5066
# Epoch 588/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4558
# Epoch 589/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7891
# Epoch 590/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.8450
# Epoch 591/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6487
# Epoch 592/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.3913
# Epoch 593/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7039
# Epoch 594/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7735
# Epoch 595/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8960
# Epoch 596/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5393
# Epoch 597/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6052
# Epoch 598/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6682
# Epoch 599/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.9717
# Epoch 600/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6821
# Epoch 601/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5792
# Epoch 602/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8238
# Epoch 603/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.3958
# Epoch 604/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4623
# Epoch 605/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5595
# Epoch 606/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4961
# Epoch 607/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7536
# Epoch 608/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6675
# Epoch 609/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.1076
# Epoch 610/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.2619
# Epoch 611/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7937
# Epoch 612/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8331
# Epoch 613/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6151
# Epoch 614/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2733
# Epoch 615/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6085
# Epoch 616/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5996
# Epoch 617/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5610
# Epoch 618/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6456
# Epoch 619/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0001
# Epoch 620/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.8939
# Epoch 621/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6107
# Epoch 622/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.2005
# Epoch 623/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6050
# Epoch 624/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7062
# Epoch 625/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.4654
# Epoch 626/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.3998
# Epoch 627/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7439
# Epoch 628/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.3365
# Epoch 629/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7985
# Epoch 630/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7849
# Epoch 631/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.9738
# Epoch 632/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.2059
# Epoch 633/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4962
# Epoch 634/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0220
# Epoch 635/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.7378
# Epoch 636/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.9109
# Epoch 637/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.0204
# Epoch 638/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4098
# Epoch 639/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5266
# Epoch 640/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.2727
# Epoch 641/1000
# ...
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Ticker"] = stock
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 8169.9595
# Epoch 2/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6856.8442
# Epoch 3/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6257.7749
# Epoch 4/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5915.4692
# Epoch 5/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5707.6567
# Epoch 6/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5392.3569
# Epoch 7/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4763.9761
# Epoch 8/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4407.0298
# Epoch 9/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4278.1274
# Epoch 10/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3986.3550
# Epoch 11/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3653.1233
# Epoch 12/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3697.9812
# Epoch 13/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3282.4268
# Epoch 14/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3227.3340
# Epoch 15/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3003.3630
# Epoch 16/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2779.3103
# Epoch 17/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2703.6396
# Epoch 18/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2717.0000
# Epoch 19/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2486.9346
# Epoch 20/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2316.6440
# Epoch 21/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2395.6113
# Epoch 22/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2218.1096
# Epoch 23/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2180.8218
# Epoch 24/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2140.1848
# Epoch 25/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2127.6919
# Epoch 26/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2178.3008
# Epoch 27/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2136.5151
# Epoch 28/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1992.4139
# Epoch 29/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2019.6237
# Epoch 30/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1967.9794
# Epoch 31/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1940.2822
# Epoch 32/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1950.6173
# Epoch 33/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1895.6182
# Epoch 34/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1973.4049
# Epoch 35/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1909.6017
# Epoch 36/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1927.4691
# Epoch 37/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1508.6216
# Epoch 38/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1194.4413
# Epoch 39/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1151.4697
# Epoch 40/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1066.2760
# Epoch 41/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 985.3510
# Epoch 42/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 901.4520
# Epoch 43/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 873.3071
# Epoch 44/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 782.7686
# Epoch 45/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 718.9904
# Epoch 46/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 627.5548
# Epoch 47/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 615.0153
# Epoch 48/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 633.8494
# Epoch 49/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 515.6709
# Epoch 50/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 457.5787
# Epoch 51/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 463.0010
# Epoch 52/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 423.3468
# Epoch 53/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 413.6969
# Epoch 54/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 371.4597
# Epoch 55/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 309.3676
# Epoch 56/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 292.0849
# Epoch 57/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 331.5218
# Epoch 58/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 297.6719
# Epoch 59/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 265.9767
# Epoch 60/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 220.3948
# Epoch 61/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 253.3765
# Epoch 62/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 196.9948
# Epoch 63/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 213.3623
# Epoch 64/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 194.9471
# Epoch 65/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 180.9832
# Epoch 66/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 181.5115
# Epoch 67/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 152.8009
# Epoch 68/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 130.6214
# Epoch 69/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 148.8579
# Epoch 70/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 124.4505
# Epoch 71/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 123.2831
# Epoch 72/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 126.3056
# Epoch 73/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 110.5010
# Epoch 74/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 93.6537
# Epoch 75/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 95.8206
# Epoch 76/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 95.6938
# Epoch 77/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 78.6249
# Epoch 78/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 93.8570
# Epoch 79/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 90.3847
# Epoch 80/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 80.1641
# Epoch 81/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 70.6912
# Epoch 82/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 70.8184
# Epoch 83/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 55.9877
# Epoch 84/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 65.3279
# Epoch 85/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 53.3043
# Epoch 86/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 54.4827
# Epoch 87/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 47.2150
# Epoch 88/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 50.6582
# Epoch 89/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 43.0783
# Epoch 90/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 42.2792
# Epoch 91/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 39.5432
# Epoch 92/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 43.6801
# Epoch 93/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 33.1798
# Epoch 94/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 36.2440
# Epoch 95/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 37.6626
# Epoch 96/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 29.6409
# Epoch 97/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 29.1798
# Epoch 98/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 32.5921
# Epoch 99/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 26.6297
# Epoch 100/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 25.0072
# Epoch 101/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 27.3237
# Epoch 102/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 27.3879
# Epoch 103/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 24.5564
# Epoch 104/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 20.9634
# Epoch 105/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 18.0690
# Epoch 106/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 19.8082
# Epoch 107/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 20.5548
# Epoch 108/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 15.8772
# Epoch 109/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 19.5819
# Epoch 110/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 19.3208
# Epoch 111/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 20.2843
# Epoch 112/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 13.6654
# Epoch 113/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 12.6348
# Epoch 114/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 13.4696
# Epoch 115/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 13.9529
# Epoch 116/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 13.9700
# Epoch 117/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 11.7456
# Epoch 118/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 11.7474
# Epoch 119/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 11.9142
# Epoch 120/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.5135
# Epoch 121/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.4811
# Epoch 122/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.8999
# Epoch 123/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.4868
# Epoch 124/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.1910
# Epoch 125/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.7919
# Epoch 126/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.3945
# Epoch 127/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.0484
# Epoch 128/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.8419
# Epoch 129/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.6274
# Epoch 130/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.8099
# Epoch 131/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.3996
# Epoch 132/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.8044
# Epoch 133/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.5089
# Epoch 134/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.4940
# Epoch 135/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.9900
# Epoch 136/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.3561
# Epoch 137/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.4164
# Epoch 138/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.8338
# Epoch 139/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.5885
# Epoch 140/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.9217
# Epoch 141/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.7191
# Epoch 142/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.0716
# Epoch 143/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.7096
# Epoch 144/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.1090
# Epoch 145/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.4283
# Epoch 146/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.0332
# Epoch 147/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.7534
# Epoch 148/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.9479
# Epoch 149/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.2597
# Epoch 150/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.4996
# Epoch 151/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.5416
# Epoch 152/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.5319
# Epoch 153/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.4340
# Epoch 154/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7639
# Epoch 155/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.9496
# Epoch 156/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.1737
# Epoch 157/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.3701
# Epoch 158/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.3349
# Epoch 159/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8374
# Epoch 160/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6156
# Epoch 161/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.3725
# Epoch 162/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.2699
# Epoch 163/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6211
# Epoch 164/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.0950
# Epoch 165/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4684
# Epoch 166/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0197
# Epoch 167/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.0206
# Epoch 168/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.3332
# Epoch 169/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7518
# Epoch 170/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4187
# Epoch 171/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.3368
# Epoch 172/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.2476
# Epoch 173/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6559
# Epoch 174/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7576
# Epoch 175/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4975
# Epoch 176/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.9817
# Epoch 177/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4705
# Epoch 178/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.8687
# Epoch 179/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.5630
# Epoch 180/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.0857
# Epoch 181/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.3193
# Epoch 182/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6987
# Epoch 183/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7953
# Epoch 184/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.3138
# Epoch 185/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.7401
# Epoch 186/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6710
# Epoch 187/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.0845
# Epoch 188/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.0580
# Epoch 189/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6141
# Epoch 190/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.5304
# Epoch 191/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.0695
# Epoch 192/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.5983
# Epoch 193/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.4823
# Epoch 194/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.0008
# Epoch 195/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0074
# Epoch 196/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.5417
# Epoch 197/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.1313
# Epoch 198/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.7963
# Epoch 199/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.7628
# Epoch 200/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6107
# Epoch 201/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.2086
# Epoch 202/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.0184
# Epoch 203/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6560
# Epoch 204/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.9432
# Epoch 205/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.0137
# Epoch 206/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.3213
# Epoch 207/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.4680
# Epoch 208/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.2645
# Epoch 209/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.1805
# Epoch 210/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6476
# Epoch 211/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.7582
# Epoch 212/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.0279
# Epoch 213/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.8381
# Epoch 214/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.8681
# Epoch 215/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.4960
# Epoch 216/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.8152
# Epoch 217/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.0260
# Epoch 218/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.7203
# Epoch 219/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.1174
# Epoch 220/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.8260
# Epoch 221/1000
# 33/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6790

# %%
stocks = ["AAPL", "MSFT", "GOOGL", "AMZN", "META", "NVDA", "TSLA"]

for stock in stocks:
    predicting_data = pd.read_csv(f"processed_stock_data/{stock}_processed.csv")
    predicting_data = predicting_data.tail(20)
    predicting_data.to_csv(f"/Users/noel_personal/Repos/TIKR/my-react-app/backend/predicting_data/{stock}.csv",index=False)
